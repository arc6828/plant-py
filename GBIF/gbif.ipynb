# %% [markdown]
# # GBIF

# %% [markdown]
# ## OCCURRENCE

# %%
import pandas as pd

# Load JSON file into DataFrame
# filename = "data/0017526-250127130748423.csv"
filename = "data/0017531-250127130748423/occurrence.txt"
df = pd.read_csv(filename, sep='\t')

# Search for rows containing "apple" in the 'name' column
keyword = "Pathum"
filtered_df = df[df['stateProvince'].str.contains(keyword, case=False, na=False)]
filtered_df
# Out:
# C:\Users\chavalit\AppData\Local\Temp\ipykernel_11868\2869753772.py:6: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, sep='\t')
#            gbifID  accessRights  bibliographicCitation  language  \
# 100    5008446435           NaN                    NaN       NaN
# 102    5008438711           NaN                    NaN       NaN
# 110    5008428425           NaN                    NaN       NaN
# 133    5008378885           NaN                    NaN       NaN
# 136    5008376274           NaN                    NaN       NaN
# ...           ...           ...                    ...       ...
# 9677   4597122322           NaN                    NaN       NaN
# 9766   4596834794           NaN                    NaN       NaN
# 10581  4516774507           NaN                    NaN       NaN
# 10646  4516644589           NaN                    NaN       NaN
# ...

# %%
list(df["vernacularName"])
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...
